# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from SALib import ProblemSpec
from seapopym.configuration.no_transport.parameter import ForcingParameters, ForcingUnit, KernelParameters
from dask.distributed import Client
import dask
import plotly.express as px
from plotly.subplots import make_subplots
from seapopym_optimization import wrapper

# %% [markdown]
# Load forcing.

# %%
STATION = "Bats"

# %%
time_start, time_end = "1998-01-01", "2022-01-01"

data = xr.open_dataset(f"../1_data_processing/1_1_Forcing/products/{STATION}_cmems.zarr", engine="zarr")
data["time"].attrs = {"axis": "T"}
data = data.sel(time=slice(time_start, time_end))
_ = data.load()

cafe_npp = xr.open_dataset(f"../1_data_processing/1_1_Forcing/products/{STATION}_cafe.zarr", engine="zarr")
cafe_npp = cafe_npp.sel(time=slice(time_start, time_end))
cafe_npp = cafe_npp.dropna("time")
cafe_npp = cafe_npp.resample(time="D").interpolate("linear")
cafe_npp.time.attrs["axis"] = "T"
_ = cafe_npp.load()

# %%
data
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:              (latitude: 1, longitude: 1, time: 8767, depth: 3)
# Coordinates:
#   * depth                (depth) int32 12B 1 2 3
#   * latitude             (latitude) float64 8B 31.6
#   * longitude            (longitude) float64 8B -64.2
#   * time                 (time) datetime64[ns] 70kB 1998-01-01 ... 2022-01-01
# Data variables: (12/13)
#     T                    (latitude, longitude, time, depth) float64 210kB 20....
#     U                    (latitude, longitude, time, depth) float64 210kB 0.0...
#     V                    (latitude, longitude, time, depth) float64 210kB -0....
#     mnkc_epi             (latitude, longitude, time) float64 70kB 0.7326 ... ...
#     mnkc_hmlmeso         (latitude, longitude, time) float64 70kB 0.6836 ... ...
#     mnkc_lmeso           (latitude, longitude, time) float64 70kB 1.118 ... 1...
#     ...                   ...
#     mnkc_mumeso          (latitude, longitude, time) float64 70kB 0.579 ... 1...
#     mnkc_umeso           (latitude, longitude, time) float64 70kB 0.3336 ... ...
#     npp                  (latitude, longitude, time) float64 70kB 450.0 ... 2...
#     pelagic_layer_depth  (latitude, longitude, time, depth) float64 210kB 100...
#     zeu                  (latitude, longitude, time) float64 70kB 66.78 ... 7...
#     zooc                 (latitude, longitude, time) float64 70kB 0.3742 ... ...

# %%
cafe_npp
# Out:
# <xarray.Dataset> Size: 140kB
# Dimensions:    (time: 8767, latitude: 1, longitude: 1)
# Coordinates:
#   * latitude   (latitude) float64 8B 31.6
#   * longitude  (longitude) float64 8B -64.2
#   * time       (time) datetime64[ns] 70kB 1998-01-01 1998-01-02 ... 2022-01-01
# Data variables:
#     CAFE       (time, latitude, longitude) float64 70kB 262.5 257.1 ... 228.4
# Attributes:
#     Conventions:  CF-1.8
#     History:      2023-01-02 08:55:09.514113 Python
#     Keywords:     Primary Production
#     PI Contact:   tryankeogh@csir.co.za
#     PI Name:      Thomas Ryan-Keogh

# %%
forcing_parameter_initial = ForcingParameters(
    temperature=ForcingUnit.from_dataset(forcing=data, name="T", resolution=0.08333, timestep=1),
    primary_production=ForcingUnit.from_dataset(cafe_npp, name="CAFE", resolution=0.08333, timestep=1),
)
# Out:
# 2024-11-20 16:50:23,078 :: Seapodym ::  WARNING ::
# |	CAFE unit is milligram / day / meter ** 2, it will be converted to kilogram / day / meter ** 2.

# %% [markdown]
# Generate initial conditions.

# %%
fg_parameters = wrapper.FunctionalGroupGeneratorNoTransport(
    [[10.38, -0.11, 150, 0.15, 1, 1, 0.1668]],
)
model = wrapper.model_generator_no_transport(
    fg_parameters=fg_parameters,
    forcing_parameters=forcing_parameter_initial,
    kernel_parameters=KernelParameters(compute_initial_conditions=True),
)
model.run()
initial_conditions = model.export_initial_conditions()
# Out:
# 2024-11-20 16:50:23,095 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:23,099 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:23,151 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:23,189 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:23,203 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:23,210 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:23,212 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:23,218 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:23,240 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:23,245 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:26,069 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.

# %% [markdown]
# Model generation used in sensibility analysis.

# %%
FORCING_PARAMETERS = ForcingParameters(
    temperature=ForcingUnit.from_dataset(data, name="T", resolution=0.08333, timestep=1),
    primary_production=ForcingUnit.from_dataset(cafe_npp, name="CAFE", resolution=0.08333, timestep=1),
    initial_condition_biomass=ForcingUnit.from_dataset(
        initial_conditions, name="initial_condition_biomass", resolution=0.08333, timestep=1
    ),
    initial_condition_production=ForcingUnit.from_dataset(
        initial_conditions, name="initial_condition_production", resolution=0.08333, timestep=1
    ),
)


def wrapper_model_generator_no_transport(fg_parameters):
    fg_parameters = wrapper.FunctionalGroupGeneratorNoTransport(np.array([fg_parameters]))
    return wrapper.model_generator_no_transport(
        fg_parameters=fg_parameters,
        forcing_parameters=FORCING_PARAMETERS,
    )
# Out:
# 2024-11-20 16:50:26,445 :: Seapodym ::  WARNING ::
# |	CAFE unit is milligram / day / meter ** 2, it will be converted to kilogram / day / meter ** 2.

# %% [markdown]
# Setup sensitivity analysis structure.

# %%
sp = ProblemSpec(
    {
        "names": [
            "energy_transfert",
            "tr_max",
            "tr_rate",
            "inv_lambda_max",
            "inv_lambda_rate",
        ],
        "groups": None,
        "bounds": [
            [0, 1],
            [0, 50],
            [-1, 0],
            [0, 1000],
            [0, 1],
        ],
        "outputs": ["mean", "variance"],
    }
)

# %% [markdown]
# Create the cost function.

# %%
@dask.delayed
def cost_function(x: np.ndarray):
    energy_transfert, tr_max, tr_rate, inv_lambda_max, inv_lambda_rate = x.T
    fg_parameters = [tr_max, tr_rate, inv_lambda_max, inv_lambda_rate, 1, 1, energy_transfert]
    model = wrapper_model_generator_no_transport(fg_parameters)

    model.run()
    biomass_forcing = model.export_biomass()

    mean = float(biomass_forcing.mean())
    variance = float(biomass_forcing.var())

    return mean, variance

# %% [markdown]
# # SOBOL SENSITIVITY ANALYSIS

# %%
client = Client()
client
# Out:
# /Users/ash/Documents/Workspaces/PhD/Seapopym-optimisation/.venv/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 59236 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:59237' processes=4 threads=8, memory=16.00 GiB>

# %%
SAMPLE_NUMBER = 20

# %%
param_values = sp.sample_sobol(SAMPLE_NUMBER)
res = [cost_function(param) for param in param_values.samples]
res = client.compute(res)
res = client.gather(res)
sp.set_results(np.asarray(res))
# Out:
# /Users/ash/Documents/Workspaces/PhD/Seapopym-optimisation/.venv/lib/python3.12/site-packages/scipy/stats/_qmc.py:958: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# 2024-11-20 16:50:30,324 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:30,326 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:30,327 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:30,330 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:30,330 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:30,331 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:30,332 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:30,333 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:30,334 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:30,334 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:30,335 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:30,335 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:30,340 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:30,340 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:30,344 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:30,349 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:30,384 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:30,384 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:30,386 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:30,388 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:30,390 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:30,391 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:30,393 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:30,395 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:30,398 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:30,398 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:30,402 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:30,412 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:30,416 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:30,417 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:30,424 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:30,425 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:30,443 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:30,448 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:30,450 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:30,460 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:30,461 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:30,464 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:30,465 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:30,465 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:30,465 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:30,467 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:30,468 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:30,469 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:30,470 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:30,470 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:30,474 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:30,476 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:30,477 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:30,509 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:30,510 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:30,511 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:30,512 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:30,514 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:30,516 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:30,516 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:30,517 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:30,521 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:30,522 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:30,525 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:30,527 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:30,527 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:30,529 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:30,530 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:30,530 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:30,531 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:30,531 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:30,535 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:30,536 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:30,536 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:30,537 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:30,544 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:30,566 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:30,570 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:30,595 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:30,596 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:30,601 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:30,601 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:30,607 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:30,624 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:33,989 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:33,995 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:33,996 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,025 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,097 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,225 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,267 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,292 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,358 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,414 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,416 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,421 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,422 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,427 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,428 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,431 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,434 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,463 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,467 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,473 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,474 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,476 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,477 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,478 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,481 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,484 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,490 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,490 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,494 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,495 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,495 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,497 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,500 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,507 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,509 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,514 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,517 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,524 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,532 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:34,534 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,536 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,536 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,537 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,538 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:34,538 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,546 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,548 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,551 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,552 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,559 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,560 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,565 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,570 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,571 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,575 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,577 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,578 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,579 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,580 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:34,585 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:34,586 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,589 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,592 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,593 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,599 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,609 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:34,614 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:34,619 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:34,623 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:34,676 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,680 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,729 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,741 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,745 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,755 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,755 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,759 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,759 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,757 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,762 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,769 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,774 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,776 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,778 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,781 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,787 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,831 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:34,835 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:34,851 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,853 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:34,858 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:34,862 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:34,865 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:34,869 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:34,883 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,895 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,909 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,910 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,913 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,914 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,918 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:34,920 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,925 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:34,950 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,954 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,955 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,957 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:34,961 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,973 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:34,976 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:34,978 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:34,984 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:34,991 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:34,992 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:35,016 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:35,023 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:35,034 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:35,044 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:35,046 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:35,049 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:35,049 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:35,050 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:35,052 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:35,056 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:35,057 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:35,057 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:35,062 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:35,066 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:35,078 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:35,081 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:35,086 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:35,089 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:35,094 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:35,108 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:35,121 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:35,125 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:35,130 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:35,131 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:35,131 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:35,138 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:35,139 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:35,145 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:35,146 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:35,166 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:35,170 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:35,177 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:35,178 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:35,182 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:35,195 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:35,199 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:35,200 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:35,207 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:35,212 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:35,216 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:35,220 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:35,227 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:35,232 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:35,239 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:35,239 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:35,243 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:35,280 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:35,284 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:35,293 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:35,295 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:35,299 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:35,312 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:35,321 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:35,323 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:35,325 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:35,331 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:35,348 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:35,348 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:35,354 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:35,358 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:35,363 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:35,364 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:35,369 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:35,370 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:35,371 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:35,375 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:35,378 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:35,385 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:35,409 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:35,415 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:35,418 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:35,419 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:35,421 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:35,422 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:35,426 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:35,435 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:35,438 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:35,440 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:35,440 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:35,444 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:35,445 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:35,445 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:35,450 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:35
:: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:52,549 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:52,562 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:52,566 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:52,583 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:52,587 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:52,600 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:52,605 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:52,619 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:52,620 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:52,631 :: Seapodym ::  DEBUG ::
# |	Direct computation for global_mask_from_nan.
#
# 2024-11-20 16:50:52,633 :: Seapodym ::  DEBUG ::
# |	Direct computation for mask_by_fgroup.
#
# 2024-11-20 16:50:52,652 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:52,656 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:52,707 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:52,725 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:52,734 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:52,735 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:52,739 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:52,745 :: Seapodym ::  DEBUG ::
# |	Direct computation for _wrapper_mesh_day_lengths.
#
# 2024-11-20 16:50:52,752 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:52,778 :: Seapodym ::  DEBUG ::
# |	Direct computation for _average_temperature.
#
# 2024-11-20 16:50:52,791 :: Seapodym ::  DEBUG ::
# |	Direct computation for _apply_coefficient_to_primary_production_helper.
#
# 2024-11-20 16:50:52,795 :: Seapodym ::  DEBUG ::
# |	Direct computation for _min_temperature_by_cohort_helper.
#
# 2024-11-20 16:50:52,795 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mask_temperature_helper.
#
# 2024-11-20 16:50:52,801 :: Seapodym ::  DEBUG ::
# |	Direct computation for _cell_area_helper.
#
# 2024-11-20 16:50:52,824 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:52,825 :: Seapodym ::  DEBUG ::
# |	Direct computation for _mortality_field_helper.
#
# 2024-11-20 16:50:52,828 :: Seapodym ::  DEBUG ::
# |	Direct computation for _production_helper.
#
# 2024-11-20 16:50:52,829 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
#
# 2024-11-20 16:50:52,913 :: Seapodym ::  DEBUG ::
# |	Direct computation for _biomass_helper.
# Samples:
# 	5 parameters: ['energy_transfert', 'tr_max', 'tr_rate', 'inv_lambda_max', 'inv_lambda_rate']
# 	240 samples
# Outputs:
# 	2 outputs: ['mean', 'variance']
# 	240 evaluations

# %%
sp.analyze_sobol()

(mean_total_Si, mean_first_Si, mean_second_Si), (var_total_Si, var_first_Si, var_second_Si) = sp.to_df()
# Out:
# /Users/ash/Documents/Workspaces/PhD/Seapopym-optimisation/.venv/lib/python3.12/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))

# %%
def plot_sobol(total_si, first_si, second_si, title):
    fig_total = px.bar(total_si, x=total_si.index, y="ST", error_y="ST_conf")
    fig_first = px.bar(first_si, x=first_si.index, y="S1", error_y="S1_conf")
    fig_second = px.bar(second_si, x=second_si.index.map(str), y="S2", error_y="S2_conf")

    figure_mean = (
        make_subplots(
            rows=3,
            cols=1,
            subplot_titles=("Total Sobol indice", "First Sobol indice", "Second Sobol indice"),
            specs=[[{"type": "bar"}], [{"type": "bar"}], [{"type": "bar"}]],
            # reduce space between the plots
            vertical_spacing=0.05,
        )
        .add_trace(fig_total.data[0], row=1, col=1)
        .add_trace(fig_first.data[0], row=2, col=1)
        .add_trace(fig_second.data[0], row=3, col=1)
    )
    figure_mean.update_layout(height=1200, width=800, title_text=title)
    return figure_mean

# %%
plot_sobol(mean_total_Si, mean_first_Si, mean_second_Si, f"Sobol indices for mean biomass in {STATION}")

# %%
plot_sobol(var_total_Si, var_first_Si, var_second_Si, f"Sobol indices for variance biomass in {STATION}")
