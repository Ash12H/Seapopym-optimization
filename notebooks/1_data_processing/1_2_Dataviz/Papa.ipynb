# %%
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# # CMEMS

# %%
data = xr.load_dataset("../1_1_Forcing/products/Papa_cmems.zarr", engine="zarr")
data.T.isel(depth=0).plot()

# %% [markdown]
# # CAFE

# %%
npp = xr.load_dataset("../1_1_Forcing/products/Papa_cafe.zarr", engine="zarr")
npp.CAFE.plot()

# %% [markdown]
# # OBSERVATIONS

# %%
obs = xr.load_dataset("../1_1_Forcing/products/Papa_obs.zarr", engine="zarr")
obs.day.dropna("time").plot(label="day")
obs.night.dropna("time").plot(label="night")
plt.legend()
