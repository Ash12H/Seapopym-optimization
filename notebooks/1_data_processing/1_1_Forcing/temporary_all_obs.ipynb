# %%
import xarray as xr

# %%
xr.open_dataset("../../../../seapopym-data/data/zooplankton_product/Papa_zooplankton.nc")
# Out:
# <xarray.Dataset> Size: 2kB
# Dimensions:    (latitude: 1, longitude: 1, layer: 1, time: 69)
# Coordinates:
#   * latitude   (latitude) int64 8B 50
#   * longitude  (longitude) int64 8B -150
#   * layer      (layer) int64 8B 0
#   * time       (time) datetime64[ns] 552B 1997-02-21 1997-06-15 ... 2020-08-20
# Data variables:
#     night      (time, latitude, longitude, layer) float64 552B ...
#     day        (time, latitude, longitude, layer) float64 552B ...
# Attributes:
#     station:        Papa
#     creation date:  2024-10-13T20:03:40.331216
#     layer:          epipelagic

# %%
xr.open_dataset("../../../../seapopym-data/data/zooplankton_product/Bats_zooplankton.nc").to_zarr("./Bats_obs.zarr")
xr.open_dataset("../../../../seapopym-data/data/zooplankton_product/Hot_zooplankton.nc").to_zarr("./Hot_obs.zarr")
xr.open_dataset("../../../../seapopym-data/data/zooplankton_product/Papa_zooplankton.nc").to_zarr("./Papa_obs.zarr")
